# %% [markdown]
# ## Programa que muestra la fecha actual:

# %%
from datetime import date

print("La fecha es: " + str(date.today()))

# %% [markdown]
# ## Conversor de parsec

# %%
parsec = (int)(input("Introduce el número de años"))
lightyears = 3.26156 * parsec

print(str(parsec) + " parsecs, son " + str(lightyears) + " años luz")
# Out:
# 1 parsecs, son 3.26156 años luz
