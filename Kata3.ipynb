# %% [markdown]
# ## Ejercicio 1

# %%
Velocidad = 49

if Velocidad > 25:
    print('Alerta de impacto de metiorito')
else:
    print('No hay peligro')
# Out:
# Alerta de impacto de metiorito

# %% [markdown]
# ## Ejercicio 2

# %%
Velocidad = 19

if Velocidad > 25:
    print('Alerta de impacto de metiorito')
elif Velocidad >= 20:
    print('El rayo se visible')
else:
    print('No hay peligro')

# %% [markdown]
# ## Ejercicio: Uso de operadores and y or

# %%
Velocidad = 25
Tamanio = 40
if Velocidad > 25 and Tamanio > 25:
    print('Peligro')
elif Velocidad >= 20:
    print('La luz es visible')
elif Tamanio < 25:
    print('Sin problemas')
else:
    print('Sin problemas')
