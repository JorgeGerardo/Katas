# %% [markdown]
# ## Ejercicio1 - Utilizar operadores aritméticos

# %%
Planeta1 = 149597870
Planeta2 = 778547200



Dis = Planeta2 - Planeta1
print('Distancia en kilometros: ' + str(Dis))

DisMillas = Dis * 0.621
print('Distancia en milllas: ' + '\t'+str(DisMillas))
# Out:
# Distancia en kilometros: 628949330
# Distancia en milllas: 	390577533.93

# %%
Planeta1 = (int)(input('Distancia del primer planeta desde el sol'))
Planeta2 = (int)(input('Distancia del segundo planeta desde el sol'))

DisKm = Planeta2 - Planeta1
print(DisKm)

# Convertir de KM a Millas
DisMi = DisKm * 0.621
print(abs(DisMi))
# Out:
# 112
# 69.55199999999999
